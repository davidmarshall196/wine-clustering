# %% [markdown]
# ### Time Series of Wikipedia Traffic
#
# This notebook takes a sample of the time series web traffic, makes some predictions with some simple time series models, and then takes one of them to make predictions on all 145,000 wikipedia sites.

# %%
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
import timeit
start_time = timeit.default_timer()
train = pd.read_csv("train_2.csv")
elapsed = timeit.default_timer() - start_time
print("Time to load data: ", round(elapsed, 2), "s")
print("Shape of Data: ", train.shape)
# Out:
# Time to load data:  16.59 s
# Shape of Data:  (145063, 804)

# %%
train.head()
# Out:
#                                                 Page  2015-07-01  2015-07-02  \
# 0            2NE1_zh.wikipedia.org_all-access_spider        18.0        11.0
# 1             2PM_zh.wikipedia.org_all-access_spider        11.0        14.0
# 2              3C_zh.wikipedia.org_all-access_spider         1.0         0.0
# 3         4minute_zh.wikipedia.org_all-access_spider        35.0        13.0
# 4  52_Hz_I_Love_You_zh.wikipedia.org_all-access_s...         NaN         NaN
#
#    2015-07-03  2015-07-04  2015-07-05  2015-07-06  2015-07-07  2015-07-08  \
# 0         5.0        13.0        14.0         9.0         9.0        22.0
# 1        15.0        18.0        11.0        13.0        22.0        11.0
# 2         1.0         1.0         0.0         4.0         0.0         3.0
# 3        10.0        94.0         4.0        26.0        14.0         9.0
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#    2015-07-09     ...      2017-09-01  2017-09-02  2017-09-03  2017-09-04  \
# 0        26.0     ...            19.0        33.0        33.0        18.0
# 1        10.0     ...            32.0        30.0        11.0        19.0
# 2         4.0     ...             6.0         6.0         7.0         2.0
# 3        11.0     ...             7.0        19.0        19.0         9.0
# 4         NaN     ...            16.0        16.0        19.0         9.0
#
#    2017-09-05  2017-09-06  2017-09-07  2017-09-08  2017-09-09  2017-09-10
# 0        16.0        27.0        29.0        23.0        54.0        38.0
# 1        54.0        25.0        26.0        23.0        13.0        81.0
# 2         4.0         7.0         3.0         4.0         7.0         6.0
# 3         6.0        16.0        19.0        30.0        38.0         4.0
# 4        20.0        23.0        28.0        14.0         8.0         7.0
#
# [5 rows x 804 columns]

# %% [markdown]
# In order to run the time series I need the data to be transposed to show 1 article per column:

# %%
train = train.transpose()
train.head()
# Out:
#                                              0       \
# Page        2NE1_zh.wikipedia.org_all-access_spider
# 2015-07-01                                       18
# 2015-07-02                                       11
# 2015-07-03                                        5
# 2015-07-04                                       13
#
#                                             1       \
# Page        2PM_zh.wikipedia.org_all-access_spider
# 2015-07-01                                      11
# 2015-07-02                                      14
# 2015-07-03                                      15
# 2015-07-04                                      18
#
#                                            2       \
# Page        3C_zh.wikipedia.org_all-access_spider
# 2015-07-01                                      1
# 2015-07-02                                      0
# 2015-07-03                                      1
# 2015-07-04                                      1
#
#                                                 3       \
# Page        4minute_zh.wikipedia.org_all-access_spider
# 2015-07-01                                          35
# 2015-07-02                                          13
# 2015-07-03                                          10
# 2015-07-04                                          94
#
#                                                        4       \
# Page        52_Hz_I_Love_You_zh.wikipedia.org_all-access_s...
# 2015-07-01                                                NaN
# 2015-07-02                                                NaN
# 2015-07-03                                                NaN
# 2015-07-04                                                NaN
#
#                                              5       \
# Page        5566_zh.wikipedia.org_all-access_spider
# 2015-07-01                                       12
# 2015-07-02                                        7
# 2015-07-03                                        4
# 2015-07-04                                        5
#
#                                                6       \
# Page        91Days_zh.wikipedia.org_all-access_spider
# 2015-07-01                                        NaN
# 2015-07-02                                        NaN
# 2015-07-03                                        NaN
# 2015-07-04                                        NaN
#
#                                               7       \
# Page        A'N'D_zh.wikipedia.org_all-access_spider
# 2015-07-01                                       118
# 2015-07-02                                        26
# 2015-07-03                                        30
# 2015-07-04                                        24
#
#                                               8       \
# Page        AKB48_zh.wikipedia.org_all-access_spider
# 2015-07-01                                         5
# 2015-07-02                                        23
# 2015-07-03                                        14
# 2015-07-04                                        12
#
#                                               9       \
# Page        ASCII_zh.wikipedia.org_all-access_spider
# 2015-07-01                                         6
# 2015-07-02                                         3
# 2015-07-03                                         5
# 2015-07-04                                        12
#
#                                   ...                          \
# Page                              ...
# 2015-07-01                        ...
# 2015-07-02                        ...
# 2015-07-03                        ...
# 2015-07-04                        ...
#
#                                                        145053  \
# Page        Drake_(músico)_es.wikipedia.org_all-access_spider
# 2015-07-01                                                NaN
# 2015-07-02                                                NaN
# 2015-07-03                                                NaN
# 2015-07-04                                                NaN
#
#                                                        145054  \
# Page        Skam_(serie_de_televisión)_es.wikipedia.org_al...
# 2015-07-01                                                NaN
# 2015-07-02                                                NaN
# 2015-07-03                                                NaN
# 2015-07-04                                                NaN
#
#                                                        145055  \
# Page        Legión_(serie_de_televisión)_es.wikipedia.org_...
# 2015-07-01                                                NaN
# 2015-07-02                                                NaN
# 2015-07-03                                                NaN
# 2015-07-04                                                NaN
#
#                                                        145056  \
# Page        Doble_tentación_es.wikipedia.org_all-access_sp...
# 2015-07-01                                                NaN
# 2015-07-02                                                NaN
# 2015-07-03                                                NaN
# 2015-07-04                                                NaN
#
#                                                        145057  \
# Page        Mi_adorable_maldición_es.wikipedia.org_all-acc...
# 2015-07-01                                                NaN
# 2015-07-02                                                NaN
# 2015-07-03                                                NaN
# 2015-07-04                                                NaN
#
#                                                        145058  \
# Page        Underworld_(serie_de_películas)_es.wikipedia.o...
# 2015-07-01                                                NaN
# 2015-07-02                                                NaN
# 2015-07-03                                                NaN
# 2015-07-04                                                NaN
#
#                                                        145059  \
# Page        Resident_Evil:_Capítulo_Final_es.wikipedia.org...
# 2015-07-01                                                NaN
# 2015-07-02                                                NaN
# 2015-07-03                                                NaN
# 2015-07-04                                                NaN
#
#                                                        145060  \
# Page        Enamorándome_de_Ramón_es.wikipedia.org_all-acc...
# 2015-07-01                                                NaN
# 2015-07-02                                                NaN
# 2015-07-03                                                NaN
# 2015-07-04                                                NaN
#
#                                                        145061  \
# Page        Hasta_el_último_hombre_es.wikipedia.org_all-ac...
# 2015-07-01                                                NaN
# 2015-07-02                                                NaN
# 2015-07-03                                                NaN
# 2015-07-04                                                NaN
#
#                                                        145062
# Page        Francisco_el_matemático_(serie_de_televisión_d...
# 2015-07-01                                                NaN
# 2015-07-02                                                NaN
# 2015-07-03                                                NaN
# 2015-07-04                                                NaN
#
# [5 rows x 145063 columns]

# %% [markdown]
# Turn the first row to a header:

# %%
new_header = train.iloc[0]
train = train[1:]
train.columns = new_header
train.head(3)
# Out:
# Page       2NE1_zh.wikipedia.org_all-access_spider  \
# 2015-07-01                                      18
# 2015-07-02                                      11
# 2015-07-03                                       5
#
# Page       2PM_zh.wikipedia.org_all-access_spider  \
# 2015-07-01                                     11
# 2015-07-02                                     14
# 2015-07-03                                     15
#
# Page       3C_zh.wikipedia.org_all-access_spider  \
# 2015-07-01                                     1
# 2015-07-02                                     0
# 2015-07-03                                     1
#
# Page       4minute_zh.wikipedia.org_all-access_spider  \
# 2015-07-01                                         35
# 2015-07-02                                         13
# 2015-07-03                                         10
#
# Page       52_Hz_I_Love_You_zh.wikipedia.org_all-access_spider  \
# 2015-07-01                                                NaN
# 2015-07-02                                                NaN
# 2015-07-03                                                NaN
#
# Page       5566_zh.wikipedia.org_all-access_spider  \
# 2015-07-01                                      12
# 2015-07-02                                       7
# 2015-07-03                                       4
#
# Page       91Days_zh.wikipedia.org_all-access_spider  \
# 2015-07-01                                       NaN
# 2015-07-02                                       NaN
# 2015-07-03                                       NaN
#
# Page       A'N'D_zh.wikipedia.org_all-access_spider  \
# 2015-07-01                                      118
# 2015-07-02                                       26
# 2015-07-03                                       30
#
# Page       AKB48_zh.wikipedia.org_all-access_spider  \
# 2015-07-01                                        5
# 2015-07-02                                       23
# 2015-07-03                                       14
#
# Page       ASCII_zh.wikipedia.org_all-access_spider  \
# 2015-07-01                                        6
# 2015-07-02                                        3
# 2015-07-03                                        5
#
# Page                                                 ...                                             \
# 2015-07-01                                           ...
# 2015-07-02                                           ...
# 2015-07-03                                           ...
#
# Page       Drake_(músico)_es.wikipedia.org_all-access_spider  \
# 2015-07-01                                               NaN
# 2015-07-02                                               NaN
# 2015-07-03                                               NaN
#
# Page       Skam_(serie_de_televisión)_es.wikipedia.org_all-access_spider  \
# 2015-07-01                                                NaN
# 2015-07-02                                                NaN
# 2015-07-03                                                NaN
#
# Page       Legión_(serie_de_televisión)_es.wikipedia.org_all-access_spider  \
# 2015-07-01                                                NaN
# 2015-07-02                                                NaN
# 2015-07-03                                                NaN
#
# Page       Doble_tentación_es.wikipedia.org_all-access_spider  \
# 2015-07-01                                                NaN
# 2015-07-02                                                NaN
# 2015-07-03                                                NaN
#
# Page       Mi_adorable_maldición_es.wikipedia.org_all-access_spider  \
# 2015-07-01                                                NaN
# 2015-07-02                                                NaN
# 2015-07-03                                                NaN
#
# Page       Underworld_(serie_de_películas)_es.wikipedia.org_all-access_spider  \
# 2015-07-01                                                NaN
# 2015-07-02                                                NaN
# 2015-07-03                                                NaN
#
# Page       Resident_Evil:_Capítulo_Final_es.wikipedia.org_all-access_spider  \
# 2015-07-01                                                NaN
# 2015-07-02                                                NaN
# 2015-07-03                                                NaN
#
# Page       Enamorándome_de_Ramón_es.wikipedia.org_all-access_spider  \
# 2015-07-01                                                NaN
# 2015-07-02                                                NaN
# 2015-07-03                                                NaN
#
# Page       Hasta_el_último_hombre_es.wikipedia.org_all-access_spider  \
# 2015-07-01                                                NaN
# 2015-07-02                                                NaN
# 2015-07-03                                                NaN
#
# Page       Francisco_el_matemático_(serie_de_televisión_de_2017)_es.wikipedia.org_all-access_spider
# 2015-07-01                                                NaN
# 2015-07-02                                                NaN
# 2015-07-03                                                NaN
#
# [3 rows x 145063 columns]

# %% [markdown]
# Check the average number of missing values for each website:

# %%
train.isna().sum().mean()
# Out:
# 48.443421134265805

# %% [markdown]
# Each page has an average of 48 missing rows. This is a lot. I'm going to do simple forwards (and backwards) fill imputation.

# %%
train = train.fillna(method = "ffill")
train.head(2)
# Out:
# Page        2NE1_zh.wikipedia.org_all-access_spider  \
# 2015-07-01                                     18.0
# 2015-07-02                                     11.0
#
# Page        2PM_zh.wikipedia.org_all-access_spider  \
# 2015-07-01                                    11.0
# 2015-07-02                                    14.0
#
# Page        3C_zh.wikipedia.org_all-access_spider  \
# 2015-07-01                                    1.0
# 2015-07-02                                    0.0
#
# Page        4minute_zh.wikipedia.org_all-access_spider  \
# 2015-07-01                                        35.0
# 2015-07-02                                        13.0
#
# Page        52_Hz_I_Love_You_zh.wikipedia.org_all-access_spider  \
# 2015-07-01                                                NaN
# 2015-07-02                                                NaN
#
# Page        5566_zh.wikipedia.org_all-access_spider  \
# 2015-07-01                                     12.0
# 2015-07-02                                      7.0
#
# Page        91Days_zh.wikipedia.org_all-access_spider  \
# 2015-07-01                                        NaN
# 2015-07-02                                        NaN
#
# Page        A'N'D_zh.wikipedia.org_all-access_spider  \
# 2015-07-01                                     118.0
# 2015-07-02                                      26.0
#
# Page        AKB48_zh.wikipedia.org_all-access_spider  \
# 2015-07-01                                       5.0
# 2015-07-02                                      23.0
#
# Page        ASCII_zh.wikipedia.org_all-access_spider  \
# 2015-07-01                                       6.0
# 2015-07-02                                       3.0
#
# Page                                                  ...                                             \
# 2015-07-01                                            ...
# 2015-07-02                                            ...
#
# Page        Drake_(músico)_es.wikipedia.org_all-access_spider  \
# 2015-07-01                                                NaN
# 2015-07-02                                                NaN
#
# Page        Skam_(serie_de_televisión)_es.wikipedia.org_all-access_spider  \
# 2015-07-01                                                NaN
# 2015-07-02                                                NaN
#
# Page        Legión_(serie_de_televisión)_es.wikipedia.org_all-access_spider  \
# 2015-07-01                                                NaN
# 2015-07-02                                                NaN
#
# Page        Doble_tentación_es.wikipedia.org_all-access_spider  \
# 2015-07-01                                                NaN
# 2015-07-02                                                NaN
#
# Page        Mi_adorable_maldición_es.wikipedia.org_all-access_spider  \
# 2015-07-01                                                NaN
# 2015-07-02                                                NaN
#
# Page        Underworld_(serie_de_películas)_es.wikipedia.org_all-access_spider  \
# 2015-07-01                                                NaN
# 2015-07-02                                                NaN
#
# Page        Resident_Evil:_Capítulo_Final_es.wikipedia.org_all-access_spider  \
# 2015-07-01                                                NaN
# 2015-07-02                                                NaN
#
# Page        Enamorándome_de_Ramón_es.wikipedia.org_all-access_spider  \
# 2015-07-01                                                NaN
# 2015-07-02                                                NaN
#
# Page        Hasta_el_último_hombre_es.wikipedia.org_all-access_spider  \
# 2015-07-01                                                NaN
# 2015-07-02                                                NaN
#
# Page        Francisco_el_matemático_(serie_de_televisión_de_2017)_es.wikipedia.org_all-access_spider
# 2015-07-01                                                NaN
# 2015-07-02                                                NaN
#
# [2 rows x 145063 columns]

# %%
train = train.fillna(method = "bfill")

# %%
train.head(2)
# Out:
# Page        2NE1_zh.wikipedia.org_all-access_spider  \
# 2015-07-01                                     18.0
# 2015-07-02                                     11.0
#
# Page        2PM_zh.wikipedia.org_all-access_spider  \
# 2015-07-01                                    11.0
# 2015-07-02                                    14.0
#
# Page        3C_zh.wikipedia.org_all-access_spider  \
# 2015-07-01                                    1.0
# 2015-07-02                                    0.0
#
# Page        4minute_zh.wikipedia.org_all-access_spider  \
# 2015-07-01                                        35.0
# 2015-07-02                                        13.0
#
# Page        52_Hz_I_Love_You_zh.wikipedia.org_all-access_spider  \
# 2015-07-01                                               38.0
# 2015-07-02                                               38.0
#
# Page        5566_zh.wikipedia.org_all-access_spider  \
# 2015-07-01                                     12.0
# 2015-07-02                                      7.0
#
# Page        91Days_zh.wikipedia.org_all-access_spider  \
# 2015-07-01                                       61.0
# 2015-07-02                                       61.0
#
# Page        A'N'D_zh.wikipedia.org_all-access_spider  \
# 2015-07-01                                     118.0
# 2015-07-02                                      26.0
#
# Page        AKB48_zh.wikipedia.org_all-access_spider  \
# 2015-07-01                                       5.0
# 2015-07-02                                      23.0
#
# Page        ASCII_zh.wikipedia.org_all-access_spider  \
# 2015-07-01                                       6.0
# 2015-07-02                                       3.0
#
# Page                                                  ...                                             \
# 2015-07-01                                            ...
# 2015-07-02                                            ...
#
# Page        Drake_(músico)_es.wikipedia.org_all-access_spider  \
# 2015-07-01                                               14.0
# 2015-07-02                                               14.0
#
# Page        Skam_(serie_de_televisión)_es.wikipedia.org_all-access_spider  \
# 2015-07-01                                               26.0
# 2015-07-02                                               26.0
#
# Page        Legión_(serie_de_televisión)_es.wikipedia.org_all-access_spider  \
# 2015-07-01                                               50.0
# 2015-07-02                                               50.0
#
# Page        Doble_tentación_es.wikipedia.org_all-access_spider  \
# 2015-07-01                                               11.0
# 2015-07-02                                               11.0
#
# Page        Mi_adorable_maldición_es.wikipedia.org_all-access_spider  \
# 2015-07-01                                               21.0
# 2015-07-02                                               21.0
#
# Page        Underworld_(serie_de_películas)_es.wikipedia.org_all-access_spider  \
# 2015-07-01                                               13.0
# 2015-07-02                                               13.0
#
# Page        Resident_Evil:_Capítulo_Final_es.wikipedia.org_all-access_spider  \
# 2015-07-01                                               13.0
# 2015-07-02                                               13.0
#
# Page        Enamorándome_de_Ramón_es.wikipedia.org_all-access_spider  \
# 2015-07-01                                               51.0
# 2015-07-02                                               51.0
#
# Page        Hasta_el_último_hombre_es.wikipedia.org_all-access_spider  \
# 2015-07-01                                               16.0
# 2015-07-02                                               16.0
#
# Page        Francisco_el_matemático_(serie_de_televisión_de_2017)_es.wikipedia.org_all-access_spider
# 2015-07-01                                               77.0
# 2015-07-02                                               77.0
#
# [2 rows x 145063 columns]

# %%
train.isna().sum().mean()
# Out:
# 0.0

# %% [markdown]
# To decide which model is best, I'll use a small sample of 100 websites:

# %%
sample = train.sample(n = 100, axis = 1)
sample.head(2)
# Out:
# Page        Handball-Europameisterschaft_2016_de.wikipedia.org_all-access_spider  \
# 2015-07-01                                                1.0
# 2015-07-02                                                3.0
#
# Page        Heribert_Sasse_de.wikipedia.org_all-access_spider  \
# 2015-07-01                                                1.0
# 2015-07-02                                                5.0
#
# Page        Go!プリンセスプリキュア_ja.wikipedia.org_desktop_all-agents  \
# 2015-07-01                                             1439.0
# 2015-07-02                                             1235.0
#
# Page        Category:Nude_crawling_women_commons.wikimedia.org_all-access_spider  \
# 2015-07-01                                                2.0
# 2015-07-02                                                1.0
#
# Page        Royal_Rumble_(2017)_es.wikipedia.org_mobile-web_all-agents  \
# 2015-07-01                                               41.0
# 2015-07-02                                               41.0
#
# Page        Auschwitz_fr.wikipedia.org_all-access_spider  \
# 2015-07-01                                          26.0
# 2015-07-02                                          23.0
#
# Page        Шехзаде_Мустафа_ru.wikipedia.org_all-access_spider  \
# 2015-07-01                                                4.0
# 2015-07-02                                                5.0
#
# Page        Newton_Knight_en.wikipedia.org_mobile-web_all-agents  \
# 2015-07-01                                              113.0
# 2015-07-02                                               96.0
#
# Page        UFC_on_Fox:_Maia_vs._Condit_en.wikipedia.org_desktop_all-agents  \
# 2015-07-01                                              486.0
# 2015-07-02                                              486.0
#
# Page        Catégorie:Sigle_de_3_caractères_fr.wikipedia.org_all-access_all-agents  \
# 2015-07-01                                              489.0
# 2015-07-02                                              512.0
#
# Page                                   ...                              \
# 2015-07-01                             ...
# 2015-07-02                             ...
#
# Page        白雪公主与猎人_zh.wikipedia.org_all-access_all-agents  \
# 2015-07-01                                            69.0
# 2015-07-02                                            55.0
#
# Page        Mika_(chanteur)_fr.wikipedia.org_desktop_all-agents  \
# 2015-07-01                                              882.0
# 2015-07-02                                              727.0
#
# Page        Alexandra_Lacrabère_fr.wikipedia.org_all-access_spider  \
# 2015-07-01                                                2.0
# 2015-07-02                                                2.0
#
# Page        File:Debbie_Does_Dallas.ogv_commons.wikimedia.org_mobile-web_all-agents  \
# 2015-07-01                                              100.0
# 2015-07-02                                              100.0
#
# Page        中田久美_ja.wikipedia.org_all-access_all-agents  \
# 2015-07-01                                        270.0
# 2015-07-02                                        231.0
#
# Page        火影忍者疾風傳_zh.wikipedia.org_all-access_all-agents  \
# 2015-07-01                                           970.0
# 2015-07-02                                          1300.0
#
# Page        Fahrenheit_451_en.wikipedia.org_desktop_all-agents  \
# 2015-07-01                                             1407.0
# 2015-07-02                                             1317.0
#
# Page        List_of_countries_by_GDP_(nominal)_en.wikipedia.org_desktop_all-agents  \
# 2015-07-01                                             9103.0
# 2015-07-02                                             8002.0
#
# Page        File:Hognose_playing_dead.webm_commons.wikimedia.org_desktop_all-agents  \
# 2015-07-01                                               15.0
# 2015-07-02                                               11.0
#
# Page        Amoklauf_von_Winnenden_de.wikipedia.org_desktop_all-agents
# 2015-07-01                                              180.0
# 2015-07-02                                              207.0
#
# [2 rows x 100 columns]

# %%
sample.shape
# Out:
# (803, 100)

# %% [markdown]
# Now withold 1 month for testing:

# %%
sample_test = sample.tail(30)
sample = sample.head(803 - 30)

# %%
sample.tail(2)
# Out:
# Page        Handball-Europameisterschaft_2016_de.wikipedia.org_all-access_spider  \
# 2017-08-10                                                4.0
# 2017-08-11                                                2.0
#
# Page        Heribert_Sasse_de.wikipedia.org_all-access_spider  \
# 2017-08-10                                                0.0
# 2017-08-11                                                1.0
#
# Page        Go!プリンセスプリキュア_ja.wikipedia.org_desktop_all-agents  \
# 2017-08-10                                              253.0
# 2017-08-11                                              200.0
#
# Page        Category:Nude_crawling_women_commons.wikimedia.org_all-access_spider  \
# 2017-08-10                                                3.0
# 2017-08-11                                                0.0
#
# Page        Royal_Rumble_(2017)_es.wikipedia.org_mobile-web_all-agents  \
# 2017-08-10                                               68.0
# 2017-08-11                                               44.0
#
# Page        Auschwitz_fr.wikipedia.org_all-access_spider  \
# 2017-08-10                                          23.0
# 2017-08-11                                          11.0
#
# Page        Шехзаде_Мустафа_ru.wikipedia.org_all-access_spider  \
# 2017-08-10                                                8.0
# 2017-08-11                                               12.0
#
# Page        Newton_Knight_en.wikipedia.org_mobile-web_all-agents  \
# 2017-08-10                                              775.0
# 2017-08-11                                              822.0
#
# Page        UFC_on_Fox:_Maia_vs._Condit_en.wikipedia.org_desktop_all-agents  \
# 2017-08-10                                               92.0
# 2017-08-11                                               63.0
#
# Page        Catégorie:Sigle_de_3_caractères_fr.wikipedia.org_all-access_all-agents  \
# 2017-08-10                                             1238.0
# 2017-08-11                                             5181.0
#
# Page                                   ...                              \
# 2017-08-10                             ...
# 2017-08-11                             ...
#
# Page        白雪公主与猎人_zh.wikipedia.org_all-access_all-agents  \
# 2017-08-10                                            57.0
# 2017-08-11                                            38.0
#
# Page        Mika_(chanteur)_fr.wikipedia.org_desktop_all-agents  \
# 2017-08-10                                              204.0
# 2017-08-11                                              223.0
#
# Page        Alexandra_Lacrabère_fr.wikipedia.org_all-access_spider  \
# 2017-08-10                                                1.0
# 2017-08-11                                                1.0
#
# Page        File:Debbie_Does_Dallas.ogv_commons.wikimedia.org_mobile-web_all-agents  \
# 2017-08-10                                              285.0
# 2017-08-11                                              295.0
#
# Page        中田久美_ja.wikipedia.org_all-access_all-agents  \
# 2017-08-10                                        268.0
# 2017-08-11                                        271.0
#
# Page        火影忍者疾風傳_zh.wikipedia.org_all-access_all-agents  \
# 2017-08-10                                           460.0
# 2017-08-11                                           525.0
#
# Page        Fahrenheit_451_en.wikipedia.org_desktop_all-agents  \
# 2017-08-10                                             1648.0
# 2017-08-11                                             1382.0
#
# Page        List_of_countries_by_GDP_(nominal)_en.wikipedia.org_desktop_all-agents  \
# 2017-08-10                                             6470.0
# 2017-08-11                                             6165.0
#
# Page        File:Hognose_playing_dead.webm_commons.wikimedia.org_desktop_all-agents  \
# 2017-08-10                                                1.0
# 2017-08-11                                                1.0
#
# Page        Amoklauf_von_Winnenden_de.wikipedia.org_desktop_all-agents
# 2017-08-10                                               91.0
# 2017-08-11                                              106.0
#
# [2 rows x 100 columns]

# %%
sample_test.tail()
# Out:
# Page        Handball-Europameisterschaft_2016_de.wikipedia.org_all-access_spider  \
# 2017-09-06                                                3.0
# 2017-09-07                                                3.0
# 2017-09-08                                                2.0
# 2017-09-09                                                2.0
# 2017-09-10                                                1.0
#
# Page        Heribert_Sasse_de.wikipedia.org_all-access_spider  \
# 2017-09-06                                                3.0
# 2017-09-07                                                6.0
# 2017-09-08                                                5.0
# 2017-09-09                                                7.0
# 2017-09-10                                                5.0
#
# Page        Go!プリンセスプリキュア_ja.wikipedia.org_desktop_all-agents  \
# 2017-09-06                                              185.0
# 2017-09-07                                              247.0
# 2017-09-08                                              168.0
# 2017-09-09                                              202.0
# 2017-09-10                                              241.0
#
# Page        Category:Nude_crawling_women_commons.wikimedia.org_all-access_spider  \
# 2017-09-06                                                3.0
# 2017-09-07                                                0.0
# 2017-09-08                                                0.0
# 2017-09-09                                                4.0
# 2017-09-10                                                4.0
#
# Page        Royal_Rumble_(2017)_es.wikipedia.org_mobile-web_all-agents  \
# 2017-09-06                                               56.0
# 2017-09-07                                               37.0
# 2017-09-08                                               50.0
# 2017-09-09                                               55.0
# 2017-09-10                                               67.0
#
# Page        Auschwitz_fr.wikipedia.org_all-access_spider  \
# 2017-09-06                                          32.0
# 2017-09-07                                          47.0
# 2017-09-08                                          87.0
# 2017-09-09                                         170.0
# 2017-09-10                                          72.0
#
# Page        Шехзаде_Мустафа_ru.wikipedia.org_all-access_spider  \
# 2017-09-06                                                3.0
# 2017-09-07                                                6.0
# 2017-09-08                                               13.0
# 2017-09-09                                                7.0
# 2017-09-10                                                9.0
#
# Page        Newton_Knight_en.wikipedia.org_mobile-web_all-agents  \
# 2017-09-06                                              666.0
# 2017-09-07                                              776.0
# 2017-09-08                                              942.0
# 2017-09-09                                              822.0
# 2017-09-10                                             1364.0
#
# Page        UFC_on_Fox:_Maia_vs._Condit_en.wikipedia.org_desktop_all-agents  \
# 2017-09-06                                               87.0
# 2017-09-07                                               80.0
# 2017-09-08                                               88.0
# 2017-09-09                                               65.0
# 2017-09-10                                               98.0
#
# Page        Catégorie:Sigle_de_3_caractères_fr.wikipedia.org_all-access_all-agents  \
# 2017-09-06                                              610.0
# 2017-09-07                                              691.0
# 2017-09-08                                              538.0
# 2017-09-09                                              519.0
# 2017-09-10                                              621.0
#
# Page                                   ...                              \
# 2017-09-06                             ...
# 2017-09-07                             ...
# 2017-09-08                             ...
# 2017-09-09                             ...
# 2017-09-10                             ...
#
# Page        白雪公主与猎人_zh.wikipedia.org_all-access_all-agents  \
# 2017-09-06                                            47.0
# 2017-09-07                                            40.0
# 2017-09-08                                            47.0
# 2017-09-09                                            70.0
# 2017-09-10                                            55.0
#
# Page        Mika_(chanteur)_fr.wikipedia.org_desktop_all-agents  \
# 2017-09-06                                              246.0
# 2017-09-07                                              237.0
# 2017-09-08                                              211.0
# 2017-09-09                                              187.0
# 2017-09-10                                              195.0
#
# Page        Alexandra_Lacrabère_fr.wikipedia.org_all-access_spider  \
# 2017-09-06                                                0.0
# 2017-09-07                                                4.0
# 2017-09-08                                                2.0
# 2017-09-09                                                2.0
# 2017-09-10                                                2.0
#
# Page        File:Debbie_Does_Dallas.ogv_commons.wikimedia.org_mobile-web_all-agents  \
# 2017-09-06                                              258.0
# 2017-09-07                                              233.0
# 2017-09-08                                              297.0
# 2017-09-09                                              311.0
# 2017-09-10                                              299.0
#
# Page        中田久美_ja.wikipedia.org_all-access_all-agents  \
# 2017-09-06                                      45354.0
# 2017-09-07                                       8686.0
# 2017-09-08                                      63059.0
# 2017-09-09                                      72225.0
# 2017-09-10                                      42704.0
#
# Page        火影忍者疾風傳_zh.wikipedia.org_all-access_all-agents  \
# 2017-09-06                                           779.0
# 2017-09-07                                           819.0
# 2017-09-08                                           829.0
# 2017-09-09                                           869.0
# 2017-09-10                                           901.0
#
# Page        Fahrenheit_451_en.wikipedia.org_desktop_all-agents  \
# 2017-09-06                                             1826.0
# 2017-09-07                                             1651.0
# 2017-09-08                                             1574.0
# 2017-09-09                                              984.0
# 2017-09-10                                             1120.0
#
# Page        List_of_countries_by_GDP_(nominal)_en.wikipedia.org_desktop_all-agents  \
# 2017-09-06                                             7972.0
# 2017-09-07                                            10351.0
# 2017-09-08                                             6094.0
# 2017-09-09                                             4364.0
# 2017-09-10                                             4866.0
#
# Page        File:Hognose_playing_dead.webm_commons.wikimedia.org_desktop_all-agents  \
# 2017-09-06                                                5.0
# 2017-09-07                                                3.0
# 2017-09-08                                                4.0
# 2017-09-09                                                5.0
# 2017-09-10                                                2.0
#
# Page        Amoklauf_von_Winnenden_de.wikipedia.org_desktop_all-agents
# 2017-09-06                                              114.0
# 2017-09-07                                               97.0
# 2017-09-08                                              113.0
# 2017-09-09                                               82.0
# 2017-09-10                                               74.0
#
# [5 rows x 100 columns]

# %% [markdown]
# The data sets match. Now I try 8 different time series models and make predictions with the test set, one after the other. I'm going to measure the time and compare the RMSE to the test set, before choosing one to predict on all the data.

# %%
import warnings
warnings.filterwarnings("ignore")

# 1. Autoregression (AR)
from statsmodels.tsa.ar_model import AR

preds_data = pd.DataFrame()
start_date = "2017-08-12"
end_date = "2017-09-10"

# Measure time
start_time = timeit.default_timer()

# Fit model
for column in sample:
    model = AR(sample[column])
    model_fit = model.fit()
# Make prediction
    yhat = model_fit.predict(start_date, end_date)
    preds_data[column] = yhat

# End time
elapsed = timeit.default_timer() - start_time

print("Time for 100 predictions: ", round(elapsed, 2), "s")
#print("RMSE: ", (((preds_data - sample_test) ** 2).mean() ** 0.5).mean())
# Out:
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# Time for 100 predictions:  1.32 s
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)

# %%
# 2. Moving Average (MA)
from statsmodels.tsa.arima_model import ARMA

preds_data = pd.DataFrame()
start_date = "2017-08-12"
end_date = "2017-09-10"

# Measure time
start_time = timeit.default_timer()

# Fit model
for column in sample:
    model = ARMA(sample[column], order = (0,1))
    model_fit = model.fit()
# Make prediction
    yhat = model_fit.predict(start_date, end_date)
    preds_data[column] = yhat

# End time
elapsed = timeit.default_timer() - start_time

print("Time for 100 predictions: ", round(elapsed, 2), "s")
print("RMSE: ", (((preds_data - sample_test) ** 2).mean() ** 0.5).mean())
# Out:
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\david\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# Time for 100 predictions:  26.28 s
# RMSE:  628.5883237010505

# %%
import warnings
warnings.filterwarnings("ignore")

# 3. Autoregressive Moving Average (ARMA)
from statsmodels.tsa.arima_model import ARMA

preds_data = pd.DataFrame()
start_date = "2017-08-12"
end_date = "2017-09-10"

# Measure time
start_time = timeit.default_timer()

# Fit model
for column in sample:
    model = ARMA(sample[column], order = (1,0))
    model_fit = model.fit()
# Make prediction
    yhat = model_fit.predict(start_date, end_date)
    preds_data[column] = yhat

# End time
elapsed = timeit.default_timer() - start_time

print("Time for 100 predictions: ", round(elapsed, 2), "s")
print("RMSE: ", (((preds_data - sample_test) ** 2).mean() ** 0.5).mean())
# Out:
# Time for 100 predictions:  23.54 s
# RMSE:  619.1067867110179

# %%
# 4. Autoregressive Integrated Moving Average (ARIMA)
from statsmodels.tsa.arima_model import ARIMA

preds_data = pd.DataFrame()
start_date = "2017-08-12"
end_date = "2017-09-10"

# Measure time
start_time = timeit.default_timer()

# Fit model
for column in sample:
    model = ARIMA(sample[column], order = (1, 0, 0))
    model_fit = model.fit()
# Make prediction
    yhat = model_fit.predict(start_date, end_date)
    preds_data[column] = yhat

# End time
elapsed = timeit.default_timer() - start_time

print("Time for 100 predictions: ", round(elapsed, 2), "s")
print("RMSE: ", (((preds_data - sample_test) ** 2).mean() ** 0.5).mean())
# Out:
# Time for 100 predictions:  11.47 s
# RMSE:  619.1067867110179

# %%
# 5. SARIMAX
from statsmodels.tsa.statespace.sarimax import SARIMAX

preds_data = pd.DataFrame()
start_date = "2017-08-12"
end_date = "2017-09-10"

# Measure time
start_time = timeit.default_timer()

# Fit model
for column in sample:
    model = SARIMAX(sample[column])
    model_fit = model.fit()
# Make prediction
    yhat = model_fit.forecast(steps = 30)
    preds_data[column] = yhat

# End time
elapsed = timeit.default_timer() - start_time

print("Time for 100 predictions: ", round(elapsed, 2), "s")
print("RMSE: ", (((preds_data - sample_test) ** 2).mean() ** 0.5).mean())
# Out:
# Time for 100 predictions:  5.95 s
# RMSE:  715.367489695995

# %%
# 6. SARIMAX parameters
from statsmodels.tsa.statespace.sarimax import SARIMAX

preds_data = pd.DataFrame()
start_date = "2017-08-12"
end_date = "2017-09-10"

# Measure time
start_time = timeit.default_timer()

# Fit model
for column in sample:
    model = SARIMAX(sample[column], order = (1,1,0))
    model_fit = model.fit()
# Make prediction
    yhat = model_fit.forecast(steps = 30)
    preds_data[column] = yhat

# End time
elapsed = timeit.default_timer() - start_time

print("Time for 100 predictions: ", round(elapsed, 2), "s")
print("RMSE: ", (((preds_data - sample_test) ** 2).mean() ** 0.5).mean())
# Out:
# Time for 100 predictions:  5.56 s
# RMSE:  552.2099410411818

# %%
# 7. Simple Exponential Smoothing (SES)
from statsmodels.tsa.holtwinters import SimpleExpSmoothing

preds_data = pd.DataFrame()
start_date = "2017-08-12"
end_date = "2017-09-10"

# Measure time
start_time = timeit.default_timer()

# Fit model
for column in sample:
    model = SimpleExpSmoothing(sample[column])
    model_fit = model.fit()
# Make prediction
    yhat = model_fit.predict(start_date, end_date)
    preds_data[column] = yhat

# End time
elapsed = timeit.default_timer() - start_time

print("Time for 100 predictions: ", round(elapsed, 2), "s")
print("RMSE: ", (((preds_data - sample_test) ** 2).mean() ** 0.5).mean())
# Out:
# Time for 100 predictions:  3.42 s
# RMSE:  532.6294859335399

# %%
# 8. Holt Winters Exponential Smoothing (HWES)
from statsmodels.tsa.holtwinters import ExponentialSmoothing

preds_data = pd.DataFrame()
start_date = "2017-08-12"
end_date = "2017-09-10"

# Measure time
start_time = timeit.default_timer()

# Fit model
for column in sample:
    model = ExponentialSmoothing(sample[column])
    model_fit = model.fit()
# Make prediction
    yhat = model_fit.predict(start_date, end_date)
    preds_data[column] = yhat

# End time
elapsed = timeit.default_timer() - start_time

print("Time for 100 predictions: ", round(elapsed, 2), "s")
print("RMSE: ", (((preds_data - sample_test) ** 2).mean() ** 0.5).mean())
# Out:
# Time for 100 predictions:  2.7 s
# RMSE:  532.6294859335399

# %% [markdown]
# Given the time taken as well as the RMSE, the best approach could simply be to do an autoregression:

# %%
train.shape
# Out:
# (803, 145063)

# %%
#sample = train.iloc[:,0:80000]
#sample.shape

# %% [markdown]
# There are a few observations which have just 1 observation. The Autoregression won't work with these columns. I need to remove them before running the model on all the data.

# %%
nunique = train.apply(pd.Series.nunique)
cols_to_drop = nunique[nunique == 1].index
sample = train.drop(cols_to_drop, axis=1)

# %%
# Autoregression (AR)
warnings.filterwarnings("ignore")

preds_data = pd.DataFrame()
start_date = "2017-09-11"
end_date = "2017-11-13"

# Measure time
start_time = timeit.default_timer()

# Fit model
for column in sample:
#    print(column, "start")
    model = AR(sample[column])
    model_fit = model.fit()
# Make prediction
    yhat = model_fit.predict(start_date, end_date)
    preds_data[column] = yhat
#    print(column, "done")
    sample.columns.get_loc(column)

# End time
elapsed = timeit.default_timer() - start_time

print("Time for All predictions: ", round(elapsed, 2), "s")
# Out:
# Time for All predictions:  4040.7 s

# %%
# preds_data.to_pickle("full_preds.pkl")
#preds_data = pd.read_pickle("full_preds.pkl")
preds_data.shape
# Out:
# (64, 145027)

# %% [markdown]
# Now I have the predictions, I just need to do a bit of data wrangling and use the key to create the submission. FIrst, add the columns I took away.

# %%
extra_cols = train[cols_to_drop]
extra_cols = extra_cols.iloc[0:64,:]
extra_cols.index = preds_data.index
preds_data = pd.concat([preds_data, extra_cols], axis=1)
preds_data.shape
# Out:
# (64, 145063)

# %%
preds_data.head(2)
# Out:
#             2NE1_zh.wikipedia.org_all-access_spider  \
# 2017-09-11                                30.398645
# 2017-09-12                                25.961315
#
#             2PM_zh.wikipedia.org_all-access_spider  \
# 2017-09-11                               29.278639
# 2017-09-12                               29.629339
#
#             3C_zh.wikipedia.org_all-access_spider  \
# 2017-09-11                               5.338112
# 2017-09-12                               5.484612
#
#             4minute_zh.wikipedia.org_all-access_spider  \
# 2017-09-11                                   20.097365
# 2017-09-12                                   20.236384
#
#             52_Hz_I_Love_You_zh.wikipedia.org_all-access_spider  \
# 2017-09-11                                          16.646249
# 2017-09-12                                          18.629958
#
#             5566_zh.wikipedia.org_all-access_spider  \
# 2017-09-11                                18.450573
# 2017-09-12                                19.298680
#
#             91Days_zh.wikipedia.org_all-access_spider  \
# 2017-09-11                                   4.428612
# 2017-09-12                                  13.698189
#
#             A'N'D_zh.wikipedia.org_all-access_spider  \
# 2017-09-11                                 43.077505
# 2017-09-12                                 52.749437
#
#             AKB48_zh.wikipedia.org_all-access_spider  \
# 2017-09-11                                 45.871557
# 2017-09-12                                 45.555685
#
#             ASCII_zh.wikipedia.org_all-access_spider  \
# 2017-09-11                                 26.727910
# 2017-09-12                                 26.784241
#
#                              ...                    \
# 2017-09-11                   ...
# 2017-09-12                   ...
#
#             xss_commons.wikimedia.org_all-access_all-agents  \
# 2017-09-11                                          43289.0
# 2017-09-12                                          43289.0
#
#             xss_de.wikipedia.org_all-access_spider  \
# 2017-09-11                                     0.0
# 2017-09-12                                     0.0
#
#             Artificial_Insemination's_Art_www.mediawiki.org_all-access_spider  \
# 2017-09-11                                                0.0
# 2017-09-12                                                0.0
#
#             Special:WhatLinksHere/File:DSO-Ensemble.jpg_www.mediawiki.org_all-access_spider  \
# 2017-09-11                                                0.0
# 2017-09-12                                                0.0
#
#             Thread:Extension_talk:Phpbb_Single_Sign-On/_www.mediawiki.org_all-access_spider  \
# 2017-09-11                                                0.0
# 2017-09-12                                                0.0
#
#             User_talk:199.15.233.174_www.mediawiki.org_all-access_spider  \
# 2017-09-11                                                0.0
# 2017-09-12                                                0.0
#
#             xss_ja.wikipedia.org_desktop_all-agents  \
# 2017-09-11                                 138722.0
# 2017-09-12                                 138722.0
#
#             ????:Andrey_Belloly_1.jpg_ru.wikipedia.org_all-access_spider  \
# 2017-09-11                                                0.0
# 2017-09-12                                                0.0
#
#             xss_ru.wikipedia.org_all-access_spider  \
# 2017-09-11                                     0.0
# 2017-09-12                                     0.0
#
#             xss_ja.wikipedia.org_all-access_spider
# 2017-09-11                                     0.0
# 2017-09-12                                     0.0
#
# [2 rows x 145063 columns]

# %% [markdown]
# Firstly, turn the data in the long form used in the submission

# %%
unstacked = pd.DataFrame(preds_data.unstack())
unstacked.shape
# Out:
# (9284032, 1)

# %%
unstacked.head(2)
# Out:
#                                                             0
# 2NE1_zh.wikipedia.org_all-access_spider 2017-09-11  30.398645
#                                         2017-09-12  25.961315

# %% [markdown]
# Now read in the final version of the key data:

# %%
keys = pd.read_csv("key_2.csv")

# %%
keys.tail(4)
# Out:
#                                                       Page            Id
# 8993902  龙生九子_zh.wikipedia.org_mobile-web_all-agents_20...  33aecaf259d1
# 8993903  龙生九子_zh.wikipedia.org_mobile-web_all-agents_20...  a36228b64466
# 8993904  龙生九子_zh.wikipedia.org_mobile-web_all-agents_20...  26887d3e5c99
# 8993905  龙生九子_zh.wikipedia.org_mobile-web_all-agents_20...  06ad06979f80

# %%
keys.shape
# Out:
# (8993906, 2)

# %% [markdown]
# Now turn the index to a column:

# %%
unstacked["key"] = unstacked.index

# %%
unstacked.head(2)
# Out:
#                                                             0  \
# 2NE1_zh.wikipedia.org_all-access_spider 2017-09-11  30.398645
#                                         2017-09-12  25.961315
#
#                                                                                                   key
# 2NE1_zh.wikipedia.org_all-access_spider 2017-09-11  (2NE1_zh.wikipedia.org_all-access_spider, 2017...
#                                         2017-09-12  (2NE1_zh.wikipedia.org_all-access_spider, 2017...

# %% [markdown]
# And split the data on the comma and space

# %%
unstacked["key"] = unstacked["key"].astype(str)
unstacked[["name", "date"]] = unstacked['key'].str.split(', ',n = 1, expand=True)

# %%
unstacked.head(2)
# Out:
#                                                             0  \
# 2NE1_zh.wikipedia.org_all-access_spider 2017-09-11  30.398645
#                                         2017-09-12  25.961315
#
#                                                                                                   key  \
# 2NE1_zh.wikipedia.org_all-access_spider 2017-09-11  ('2NE1_zh.wikipedia.org_all-access_spider', Ti...
#                                         2017-09-12  ('2NE1_zh.wikipedia.org_all-access_spider', Ti...
#
#                                                                                           name  \
# 2NE1_zh.wikipedia.org_all-access_spider 2017-09-11  ('2NE1_zh.wikipedia.org_all-access_spider'
#                                         2017-09-12  ('2NE1_zh.wikipedia.org_all-access_spider'
#
#                                                                                            date
# 2NE1_zh.wikipedia.org_all-access_spider 2017-09-11  Timestamp('2017-09-11 00:00:00', freq='D'))
#                                         2017-09-12  Timestamp('2017-09-12 00:00:00', freq='D'))

# %% [markdown]
# Now trim off the edges:

# %%
unstacked["name"] = unstacked["name"].str[2:-1]
unstacked["date"] = unstacked["date"].str[11:-22]

# %%
unstacked.head(2)
# Out:
#                                                             0  \
# 2NE1_zh.wikipedia.org_all-access_spider 2017-09-11  30.398645
#                                         2017-09-12  25.961315
#
#                                                                                                   key  \
# 2NE1_zh.wikipedia.org_all-access_spider 2017-09-11  ('2NE1_zh.wikipedia.org_all-access_spider', Ti...
#                                         2017-09-12  ('2NE1_zh.wikipedia.org_all-access_spider', Ti...
#
#                                                                                        name  \
# 2NE1_zh.wikipedia.org_all-access_spider 2017-09-11  2NE1_zh.wikipedia.org_all-access_spider
#                                         2017-09-12  2NE1_zh.wikipedia.org_all-access_spider
#
#                                                           date
# 2NE1_zh.wikipedia.org_all-access_spider 2017-09-11  2017-09-11
#                                         2017-09-12  2017-09-12

# %% [markdown]
# And concat them together using a hyphen:

# %%
unstacked["joining"] = unstacked["name"].map(str) + "_" + unstacked["date"].map(str)

# %% [markdown]
# Merge the 2 datasets togther:

# %%
final = pd.merge(keys, unstacked, how = "left", left_on = "Page", right_on = "joining")

# %% [markdown]
# Finally, select only the columns I need and rename them:

# %%
final = final.iloc[:,0:3]
final.columns = ["Page", "Id", "Views"]
final = final[["Id", "Views"]]
final.head(2)
# Out:
#              Id       Views
# 0  0b293039387a  587.635642
# 1  7114389dd824  694.114726

# %% [markdown]
# There are some missing somehow. I will predict 0 and also turn the negative predictions to 0 and round to intgers.

# %%
import numpy as np
final['Views'] = np.where(final['Views'] >= 0, final['Views'], 0)

# %%
final["Views"] = round(final["Views"],0)

# %% [markdown]
# And turn into a csv for submission:

# %%
# final.to_csv("final_sub.csv", index = False)
